# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import pandas as pd
df = pd.read_csv("/content/gdrive/MyDrive/Python/Prediksi-Penyakit-Jantung/heart_disease_dataset.xlsx")
df.head()
